# %%
from matplotlib import pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('numbers')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'r:')
plt.ylabel('numbers')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro:')
plt.ylabel('numbers')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'k:')
plt.ylabel('numbers')
plt.show()

# %%
import numpy as np
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(1, figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
import pandas as pd
x=pd.DataFrame(np.random.random(10,4),index=pd.data_range('1/1/2000',periods=10),columns='ABCD')
x.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-fb5930399be4> in <module>()
#       1 import pandas as pd
# ----> 2 x=pd.DataFrame(np.random.random(10,4),index=pd.data_range('1/1/2000',periods=10),columns='ABCD')
#       3 x.plot()
#
# mtrand.pyx in mtrand.RandomState.random_sample()
#
# TypeError: random_sample() takes at most 1 positional argument (2 given)
