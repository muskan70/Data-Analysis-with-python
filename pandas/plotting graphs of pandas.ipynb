# %%
from matplotlib import pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('numbers')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'r:')
plt.ylabel('numbers')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro:')
plt.ylabel('numbers')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'k:')
plt.ylabel('numbers')
plt.show()

# %%
import numpy as np
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(1, figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
import pandas as pd
x=pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2000',periods=10),columns='ABCD')
x.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-dff18fe5809d> in <module>()
#       1 import pandas as pd
# ----> 2 x=pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2000',periods=10),columns='ABCD')
#       3 x.plot()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     359             else:
#     360                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 361                                          copy=copy)
#     362         elif isinstance(data, (list, types.GeneratorType)):
#     363             if isinstance(data, types.GeneratorType):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     522                     raise_with_traceback(e)
#     523
# --> 524         index, columns = _get_axes(*values.shape)
#     525         values = values.T
#     526
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _get_axes(N, K, index, columns)
#     489                 columns = _default_index(K)
#     490             else:
# --> 491                 columns = _ensure_index(columns)
#     492             return index, columns
#     493
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _ensure_index(index_like, copy)
#    4210             index_like = copy(index_like)
#    4211
# -> 4212     return Index(index_like)
#    4213
#    4214
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     353                          **kwargs)
#     354         elif data is None or is_scalar(data):
# --> 355             cls._scalar_data_error(data)
#     356         else:
#     357             if (tupleize_cols and isinstance(data, list) and data and
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _scalar_data_error(cls, data)
#     708         raise TypeError('{0}(...) must be called with a collection of some '
#     709                         'kind, {1} was passed'.format(cls.__name__,
# --> 710                                                       repr(data)))
#     711
#     712     @classmethod
#
# TypeError: Index(...) must be called with a collection of some kind, 'ABCD' was passed
