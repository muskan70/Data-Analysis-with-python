# %%
from xlrd import open_workbook
import numpy as np
wb=open_workbook('Book1.xlsx')
sheet=wb.sheet_by_name('Sheet1')
row=sheet.nrows
col=sheet.ncols
l=[]
for i in range(1,row):
    l.append(sheet.cell(i,1).value)
print(l)
m=[]
for i in range(1,row):
    m.append(sheet.cell(i,2).value)
print(m)
x=np.array(l)
print("Mean age of students",np.mean(x));
# Out:
# [21.0, 23.0, 22.0, 21.0, 23.0, 20.0, 19.0, 22.0, 18.0, 21.0, 24.0, 21.0, 22.0, 20.0, 26.0, 21.0, 25.0, 24.0, 23.0, 21.0, 22.0, 22.0, 19.0, 20.0, 24.0, 23.0, 21.0, 22.0, 22.0, 20.0, 23.0, 22.0, 21.0, 22.0, 23.0, 22.0, 21.0, 20.0, 20.0, 21.0, 24.0, 23.0, 22.0, 19.0, 21.0, 20.0, 18.0, 29.0, 22.0, 21.0, 22.0, 23.0, 25.0, 26.0, 20.0, 19.0, 25.0, 23.0, 21.0, 22.0]
# [92.0, 94.0, 98.0, 78.0, 75.0, 70.0, 56.0, 43.0, 89.0, 56.0, 67.0, 58.0, 83.0, 34.0, 46.0, 57.0, 72.0, 74.0, 68.0, 90.0, 93.0, 40.0, 23.0, 67.0, 69.0, 52.0, 65.0, 72.0, 71.0, 70.0, 89.0, 80.0, 82.0, 69.0, 39.0, 48.0, 50.0, 52.0, 61.0, 63.0, 40.0, 79.0, 94.0, 90.0, 84.0, 93.0, 49.0, 64.0, 67.0, 78.0, 73.0, 55.0, 44.0, 99.0, 100.0, 45.0, 33.0, 88.0, 77.0, 66.0]
# Mean age of students 21.866666666666667

# %%
import pandas as pd
import numpy as np
p=pd.Series(l)
print(x.pct_change())
# Out:
# 0          NaN
# 1     0.095238
# 2    -0.043478
# 3    -0.045455
# 4     0.095238
# 5    -0.130435
# 6    -0.050000
# 7     0.157895
# 8    -0.181818
# 9     0.166667
# 10    0.142857
# 11   -0.125000
# 12    0.047619
# 13   -0.090909
# 14    0.300000
# 15   -0.192308
# 16    0.190476
# 17   -0.040000
# 18   -0.041667
# 19   -0.086957
# 20    0.047619
# 21    0.000000
# 22   -0.136364
# 23    0.052632
# 24    0.200000
# 25   -0.041667
# 26   -0.086957
# 27    0.047619
# 28    0.000000
# 29   -0.090909
# 30    0.150000
# 31   -0.043478
# 32   -0.045455
# 33    0.047619
# 34    0.045455
# 35   -0.043478
# 36   -0.045455
# 37   -0.047619
# 38    0.000000
# 39    0.050000
# 40    0.142857
# 41   -0.041667
# 42   -0.043478
# 43   -0.136364
# 44    0.105263
# 45   -0.047619
# 46   -0.100000
# 47    0.611111
# 48   -0.241379
# 49   -0.045455
# 50    0.047619
# 51    0.045455
# 52    0.086957
# 53    0.040000
# 54   -0.230769
# 55   -0.050000
# 56    0.315789
# 57   -0.080000
# 58   -0.086957
# 59    0.047619
# dtype: float64

# %%
print(x.rank())
# Out:
# 0     21.0
# 1     46.0
# 2     34.5
# 3     21.0
# 4     46.0
# 5     10.5
# 6      4.5
# 7     34.5
# 8      1.5
# 9     21.0
# 10    52.5
# 11    21.0
# 12    34.5
# 13    10.5
# 14    58.5
# 15    21.0
# 16    56.0
# 17    52.5
# 18    46.0
# 19    21.0
# 20    34.5
# 21    34.5
# 22     4.5
# 23    10.5
# 24    52.5
# 25    46.0
# 26    21.0
# 27    34.5
# 28    34.5
# 29    10.5
# 30    46.0
# 31    34.5
# 32    21.0
# 33    34.5
# 34    46.0
# 35    34.5
# 36    21.0
# 37    10.5
# 38    10.5
# 39    21.0
# 40    52.5
# 41    46.0
# 42    34.5
# 43     4.5
# 44    21.0
# 45    10.5
# 46     1.5
# 47    60.0
# 48    34.5
# 49    21.0
# 50    34.5
# 51    46.0
# 52    56.0
# 53    58.5
# 54    10.5
# 55     4.5
# 56    56.0
# 57    46.0
# 58    21.0
# 59    34.5
# dtype: float64

# %%
p=pd.Series(l)
q=pd.Series(m)
print(p.corr(q))
# Out:
# -0.026799465793619016

# %%
from matplotlib import pyplot as plt
plt.plot(p)
plt.show()
plt.plot(q)
plt.show()
